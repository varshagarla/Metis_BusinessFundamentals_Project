# %%
import pandas as pd
import os

# %%
nypd_file_path = '/Users/varshagarla/Desktop/Business_Fundamentals/NYPD_Complaint_Data_Historic.csv'

# %%
os.path.exists(nypd_file_path)
# Out:
# True

# %%
df = pd.read_csv(nypd_file_path)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   700381962   05/28/2015     15:00:00          NaN          NaN
# 1   642234217   10/28/2013     13:50:00   10/28/2013     13:50:00
# 2   242465164   05/09/2012     20:50:00   05/09/2012     21:00:00
# 3   927207428   01/03/2014     13:30:00   01/03/2014     13:35:00
# 4   492142357   04/13/2016     00:00:00          NaN          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         46.0  06/01/2015    578                   HARRASSMENT 2  638.0  ...
# 1        120.0  10/28/2013    351  CRIMINAL MISCHIEF & RELATED OF  259.0  ...
# 2         24.0  05/09/2012    236               DANGEROUS WEAPONS  782.0  ...
# 3        108.0  01/03/2014    109                   GRAND LARCENY  409.0  ...
# 4         40.0  04/13/2016    351  CRIMINAL MISCHIEF & RELATED OF  258.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# ...

# %% [markdown]
# After looking at head of dataset, we can already see some missing NaN values. Need to explore further.

# %%
df.tail()
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 6983202   225471008   12/02/2018     04:15:00   12/02/2018     04:17:00
# 6983203   368441925   01/20/2018     00:08:00   04/26/2019     12:00:00
# 6983204   146134182   08/03/2018     22:30:00   08/04/2018     06:30:00
# 6983205   763119484   12/10/2018     11:00:00   12/21/2018     15:00:00
# 6983206   176655779   11/15/2018     10:00:00   03/23/2019     15:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  \
# 6983202        109.0  12/02/2018    344    ASSAULT 3 & RELATED OFFENSES
# 6983203         25.0  04/26/2019    361   OFF. AGNST PUB ORD SENSBLTY &
# 6983204         41.0  08/04/2018    121  CRIMINAL MISCHIEF & RELATED OF
# 6983205        107.0  04/10/2019    340                          FRAUDS
# 6983206         67.0  04/11/2019    110  GRAND LARCENY OF MOTOR VEHICLE
#
#          PD_CD  ... SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# ...

# %%
# dataset size
print('Observations: ', df.shape[0])

# number of columns
print('Columns: ', df.shape[1])
# Out:
# Observations:  6983207
# Columns:  35

# %% [markdown]
# Dataset contains over 6 million complaints from 2006 to 2019, with 35 fields each.

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE',
#        'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# ADDR_PCT_CD          float64
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# BORO_NM               object
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# JURIS_DESC            object
# JURISDICTION_CODE    float64
# PARKS_NM              object
# HADEVELOPT            object
# HOUSING_PSA           object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# SUSP_AGE_GROUP        object
# SUSP_RACE             object
# SUSP_SEX              object
# TRANSIT_DISTRICT     float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# PATROL_BORO           object
# STATION_NAME          object
# ...

# %% [markdown]
# - CMPLNT_NUM:	Randomly generated persistent ID for each complaint Number
# - CMPLNT_FR_DT:	Exact date of occurrence for the reported event (or starting date of occurrence, if CMPLNT_TO_DT exists)
# - CMPLNT_FR_TM:	Exact time of occurrence for the reported event (or starting time of occurrence, if CMPLNT_TO_TM exists)
# - CMPLNT_TO_DT:	Ending date of occurrence for the reported event, if exact time of occurrence is unknown
# - CMPLNT_TO_TM:	Ending time of occurrence for the reported event, if exact time of occurrence is unknown
# - ADDR_PCT_CD:	The precinct in which the incident occurred
# - RPT_DT:	Date event was reported to police
# - KY_CD:	Three digit offense classification code
# - OFNS_DESC:	Description of offense corresponding with key code
# - PD_CD:	Three digit internal classification code (more granular than Key Code)
# - PD_DESC:	Description of internal classification corresponding with PD code (more granular than Offense Description)
# - CRM_ATPT_CPTD_CD:	Indicator of whether crime was successfully completed or attempted, but failed or was interrupted prematurely
# - LAW_CAT_CD:	Level of offense: felony, misdemeanor, violation
# - BORO_NM:	The name of the borough in which the incident occurred
# - LOC_OF_OCCUR_DESC:	Specific location of occurrence in or around the premises; inside, opposite of, front of, rear of
# - PREM_TYP_DESC:	Specific description of premises; grocery store, residence, street, etc.
# - JURIS_DESC:	Description of the jurisdiction code
# - JURISDICTION_CODE:	Jurisdiction responsible for incident. Either internal, like Police(0), Transit(1), and Housing(2); or external(3), like Correction, Port Authority, etc.
# - PARKS_NM:	Name of NYC park, playground or greenspace of occurrence, if applicable (state parks are not included)
# - HADEVELOPT:	Name of NYCHA housing development of occurrence, if applicable
# - HOUSING_PSA:	Development Level Code
# - X_COORD_CD:	X-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
# - Y_COORD_CD:	Y-coordinate for New York State Plane Coordinate System, Long Island Zone, NAD 83, units feet (FIPS 3104)
# - SUSP_AGE_GROUP:	Suspect’s Age Group
# - SUSP_RACE:	Suspect’s Race Description
# - SUSP_SEX:	Suspect’s Sex Description
# - TRANSIT_DISTRICT:	Transit district in which the offense occurred.
# - Latitude:	Midblock Latitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)
# - Longitude:	Midblock Longitude coordinate for Global Coordinate System, WGS 1984, decimal degrees (EPSG 4326)
# - Lat_Lon:	Geospatial Location Point (latitude and Longitude combined)
# - PATROL_BORO: The name of the patrol borough in which the incident occurred
# - STATION_NAME:	Transit station name
# - VIC_AGE_GROUP:	Victim’s Age Group
# - VIC_RACE:	Victim’s Race Description
# - VIC_SEX:	Victim’s Sex Description

# %%
# See percentage of missing values for each column
(df.isna().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# PARKS_NM             99.641311
# STATION_NAME         97.750546
# TRANSIT_DISTRICT     97.750546
# HADEVELOPT           95.044855
# HOUSING_PSA          92.311427
# SUSP_AGE_GROUP       67.412766
# SUSP_SEX             49.724231
# SUSP_RACE            47.815166
# CMPLNT_TO_DT         23.891258
# CMPLNT_TO_TM         23.826145
# VIC_AGE_GROUP        23.462630
# LOC_OF_OCCUR_DESC    21.193586
# PREM_TYP_DESC         0.568965
# Y_COORD_CD            0.344598
# X_COORD_CD            0.344598
# Lat_Lon               0.344598
# Latitude              0.344598
# Longitude             0.344598
# OFNS_DESC             0.269575
# BORO_NM               0.156003
# PATROL_BORO           0.090531
# PD_DESC               0.083987
# PD_CD                 0.083987
# JURISDICTION_CODE     0.083987
# ADDR_PCT_CD           0.031017
# CMPLNT_FR_DT          0.009380
# VIC_RACE              0.004411
# VIC_SEX               0.004396
# CMPLNT_FR_TM          0.000687
# CRM_ATPT_CPTD_CD      0.000100
# ...

# %% [markdown]
# #### Observe crime type

# %%
display(df.OFNS_DESC.unique())
# Out:
# array(['HARRASSMENT 2', 'CRIMINAL MISCHIEF & RELATED OF',
#        'DANGEROUS WEAPONS', 'GRAND LARCENY', 'PETIT LARCENY',
#        'ASSAULT 3 & RELATED OFFENSES', 'FORGERY', 'DANGEROUS DRUGS',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'FELONY ASSAULT',
#        'INTOXICATED & IMPAIRED DRIVING', 'VEHICLE AND TRAFFIC LAWS',
#        'BURGLARY', 'OFFENSES AGAINST PUBLIC ADMINI', 'ROBBERY', 'RAPE',
#        'OFFENSES AGAINST THE PERSON', 'MISCELLANEOUS PENAL LAW',
#        'OTHER STATE LAWS (NON PENAL LA', 'GRAND LARCENY OF MOTOR VEHICLE',
#        "BURGLAR'S TOOLS", 'CRIMINAL TRESPASS',
#        'POSSESSION OF STOLEN PROPERTY', 'THEFT-FRAUD',
#        'MURDER & NON-NEGL. MANSLAUGHTER', 'THEFT OF SERVICES', 'ARSON',
#        'ADMINISTRATIVE CODE', 'OFFENSES INVOLVING FRAUD',
#        'UNAUTHORIZED USE OF A VEHICLE', 'OTHER OFFENSES RELATED TO THEF',
#        'FRAUDS', 'SEX CRIMES', 'OFFENSES RELATED TO CHILDREN',
#        'OFFENSES AGAINST PUBLIC SAFETY', nan, 'DISORDERLY CONDUCT',
# ...

# %%
# Types of crimes (top 10)
df.OFNS_DESC.value_counts().iloc[:10]
# Out:
# PETIT LARCENY                     1165360
# HARRASSMENT 2                      880644
# ASSAULT 3 & RELATED OFFENSES       731300
# CRIMINAL MISCHIEF & RELATED OF     699377
# GRAND LARCENY                      607704
# DANGEROUS DRUGS                    418955
# OFF. AGNST PUB ORD SENSBLTY &      368963
# FELONY ASSAULT                     265819
# ROBBERY                            253421
# BURGLARY                           239063
# Name: OFNS_DESC, dtype: int64

# %% [markdown]
# Since we are interested in analyzing sexual violence, let's look at offenses tagged with 'RAPE' and 'SEX CRIMES'

# %%
df[df['OFNS_DESC']=='RAPE']
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 59        659576310   05/10/2016     10:00:00   05/10/2016     12:35:00
# 355       248026406   04/06/2013     21:30:00   04/06/2013     22:30:00
# 675       387083608   11/28/2012     10:00:00   11/28/2012     11:00:00
# 1819      496351769   10/18/2012     01:55:00   10/18/2012     02:04:00
# 1918      602546943   09/12/2014     17:30:00   09/12/2014     18:53:00
# ...             ...          ...          ...          ...          ...
# 6982719   641530684   12/01/2014     20:00:00   12/31/2014     21:00:00
# 6982789   223341146   12/30/2018     17:00:00   12/31/2018     02:00:00
# 6983138   758182450   05/10/2018     23:30:00   05/11/2018     00:20:00
# 6983152   108620051   06/01/2018     02:30:00   06/01/2018     05:30:00
# 6983160   294901650   09/05/2015     12:00:00   09/05/2015     12:30:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD OFNS_DESC  PD_CD  ... SUSP_SEX  \
# ...

# %% [markdown]
# There are about 21 thousand complaints for rape.

# %%
df[df['OFNS_DESC']=='SEX CRIMES']
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 446       964712641   09/24/2017     15:45:00          NaN          NaN
# 544       713600785   06/02/2015     22:30:00   06/02/2015     22:36:00
# 554       921800581   10/05/2017     20:38:00   10/05/2017     20:45:00
# 640       419120230   12/01/2015     11:24:00          NaN          NaN
# 758       350958635   01/31/2015     16:00:00   01/31/2015     16:01:00
# ...             ...          ...          ...          ...          ...
# 6983179   965962172   01/01/2018     00:00:00   03/31/2019     23:59:00
# 6983183   853799275   01/01/2017     00:01:00   12/31/2018     14:00:00
# 6983184   461762281   06/01/2017     00:00:00   02/14/2019     23:59:00
# 6983196   249377210   07/10/2018     19:00:00   07/10/2018     20:00:00
# 6983197   554488139   07/21/2018     06:15:00          NaN          NaN
#
#          ADDR_PCT_CD      RPT_DT  KY_CD   OFNS_DESC  PD_CD  ... SUSP_SEX  \
# ...

# %% [markdown]
# There are about 85,000 complaints for sex crimes.

# %%
df[df['OFNS_DESC']=='FELONY SEX CRIMES']
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 471669   584259644   06/16/2019     20:50:00   06/16/2019     21:10:00
# 493530   836875675   06/30/2019     15:49:00          NaN          NaN
# 769874   369880838   09/19/2019     16:45:00   09/19/2019     17:16:00
# 786669   494348594   09/26/2019     13:45:00   09/26/2019     13:50:00
# 806350   570722879   03/17/2019     19:00:00          NaN          NaN
# 838331   311700908   05/20/2019     08:00:00   07/26/2019     08:00:00
# 843047   496407481   11/14/2019     16:30:00   11/14/2019     17:00:00
# 844278   672194546   11/15/2019     15:00:00   11/15/2019     21:00:00
# 871275   681382340   10/16/2019     14:30:00   10/16/2019     14:40:00
# 888925   249541146   12/16/2019     19:15:00   12/16/2019     19:20:00
#
#         ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 471669         52.0  06/16/2019    116  FELONY SEX CRIMES  100.0  ...
# ...

# %% [markdown]
# 10 complaints for felony sex crimes.

# %% [markdown]
# #### Clean data / handle NaN values

# %% [markdown]
# Drop entire rows that have missing values in important columns. For cases in which we don't want to drop the entire row, fill with "UNKNOWN". Drop entire columns that have a lot of missing values and are not important to the analysis.

# %%
# Drop columns that have over 90% missing values
df.drop(['PARKS_NM', 'STATION_NAME', 'TRANSIT_DISTRICT', 'HADEVELOPT', 'HOUSING_PSA'], axis='columns', inplace=True)

# %%
df.shape
# Out:
# (6983207, 30)

# %%
#df[df['OFNS_DESC']=='SEX CRIMES'].PATROL_BORO.head()

# %%
# Drop rows with missing values for:
# offense description, boro name, date, time, latitude, longitude
df.dropna(subset=['OFNS_DESC', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'Latitude', 'Longitude'], inplace=True)

# %%
df.shape
# Out:
# (6929352, 30)

# %%
# Drop columns that are not important for crime analysis
df.drop(['KY_CD', 'PD_CD', 'JURISDICTION_CODE'], axis='columns', inplace=True)

# %%
df.shape
# Out:
# (6929352, 27)

# %%
(df.isna().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# SUSP_AGE_GROUP       67.370066
# SUSP_SEX             49.658107
# SUSP_RACE            47.753686
# CMPLNT_TO_DT         23.777519
# CMPLNT_TO_TM         23.712852
# VIC_AGE_GROUP        23.372979
# LOC_OF_OCCUR_DESC    21.180307
# PREM_TYP_DESC         0.476192
# VIC_RACE              0.004344
# VIC_SEX               0.004329
# PATROL_BORO           0.001111
# CRM_ATPT_CPTD_CD      0.000101
# ADDR_PCT_CD           0.000029
# LAW_CAT_CD            0.000000
# RPT_DT                0.000000
# CMPLNT_FR_TM          0.000000
# Lat_Lon               0.000000
# Longitude             0.000000
# Latitude              0.000000
# OFNS_DESC             0.000000
# BORO_NM               0.000000
# PD_DESC               0.000000
# Y_COORD_CD            0.000000
# X_COORD_CD            0.000000
# JURIS_DESC            0.000000
# CMPLNT_FR_DT          0.000000
# CMPLNT_NUM            0.000000
# dtype: float64

# %%
# df[df['OFNS_DESC']=='SEX CRIMES'].tail()

# %%
# Drop columns for end date and end time of occurrence (usually same day as start)
df.drop(['CMPLNT_TO_DT', 'CMPLNT_TO_TM'], axis='columns', inplace=True)

# %%
df.shape
# Out:
# (6929352, 25)

# %% [markdown]
# #### Create "sex_crimes" dataframe with complaints where offense description contains "rape" or "sex crimes"

# %%
sex_crimes = df[df.OFNS_DESC.str.contains('SEX CRIMES|RAPE')]

# %%
sex_crimes.shape
# Out:
# (104211, 25)

# %%
# Percentage of missing values in each column
(sex_crimes.isna().sum()/sex_crimes.shape[0]*100).sort_values(ascending=False)
# Out:
# SUSP_AGE_GROUP       55.719646
# SUSP_SEX             33.085759
# SUSP_RACE            32.430358
# LOC_OF_OCCUR_DESC    17.829212
# VIC_AGE_GROUP         4.602201
# PREM_TYP_DESC         0.602624
# VIC_SEX               0.000960
# VIC_RACE              0.000960
# PATROL_BORO           0.000960
# Y_COORD_CD            0.000000
# Lat_Lon               0.000000
# Longitude             0.000000
# Latitude              0.000000
# CMPLNT_NUM            0.000000
# X_COORD_CD            0.000000
# CMPLNT_FR_DT          0.000000
# BORO_NM               0.000000
# LAW_CAT_CD            0.000000
# CRM_ATPT_CPTD_CD      0.000000
# PD_DESC               0.000000
# OFNS_DESC             0.000000
# RPT_DT                0.000000
# ADDR_PCT_CD           0.000000
# CMPLNT_FR_TM          0.000000
# JURIS_DESC            0.000000
# dtype: float64

# %%
sex_crimes.SUSP_SEX.value_counts()
# Out:
# M    60316
# F     5657
# U     3759
# Name: SUSP_SEX, dtype: int64

# %%
sex_crimes.SUSP_AGE_GROUP.value_counts()
# Out:
# 25-44      19072
# UNKNOWN     7724
# 18-24       7564
# 45-64       7014
# <18         3862
# 65+          904
# 324            1
# -941           1
# 2018           1
# 1017           1
# -978           1
# Name: SUSP_AGE_GROUP, dtype: int64

# %%
# Replace all NaN values with UNKNOWN
# columns: SUSP_AGE_GROUP, SUSP_SEX, SUSP_RACE, LOC_OF_OCCUR_DESC, VIC_AGE_GROUP, PREM_TYP_DESC, VIC_SEX, VIC_RACE, PATROL_BORO 

sex_crimes.fillna({'SUSP_AGE_GROUP':'UNKNOWN','SUSP_SEX':'UNKNOWN','SUSP_RACE':'UNKNOWN','LOC_OF_OCCUR_DESC':'UNKNOWN','VIC_AGE_GROUP':'UNKNOWN','PREM_TYP_DESC':'UNKNOWN','VIC_SEX':'UNKNOWN','VIC_RACE':'UNKNOWN','PATROL_BORO':'UNKNOWN'}, inplace=True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# Percentage of missing values in each column
(sex_crimes.isna().sum()/sex_crimes.shape[0]*100).sort_values(ascending=False)
# Out:
# CMPLNT_NUM           0.0
# X_COORD_CD           0.0
# VIC_RACE             0.0
# VIC_AGE_GROUP        0.0
# PATROL_BORO          0.0
# Lat_Lon              0.0
# Longitude            0.0
# Latitude             0.0
# SUSP_SEX             0.0
# SUSP_RACE            0.0
# SUSP_AGE_GROUP       0.0
# Y_COORD_CD           0.0
# JURIS_DESC           0.0
# CMPLNT_FR_DT         0.0
# PREM_TYP_DESC        0.0
# LOC_OF_OCCUR_DESC    0.0
# BORO_NM              0.0
# LAW_CAT_CD           0.0
# CRM_ATPT_CPTD_CD     0.0
# PD_DESC              0.0
# OFNS_DESC            0.0
# RPT_DT               0.0
# ADDR_PCT_CD          0.0
# CMPLNT_FR_TM         0.0
# VIC_SEX              0.0
# dtype: float64

# %%
sex_crimes.shape
# Out:
# (104211, 25)

# %% [markdown]
# #### Now take a final look at sex_crimes dataframe and see if there is any more cleaning to do

# %%
sex_crimes.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'ADDR_PCT_CD', 'RPT_DT',
#        'OFNS_DESC', 'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'X_COORD_CD',
#        'Y_COORD_CD', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'Latitude',
#        'Longitude', 'Lat_Lon', 'PATROL_BORO', 'VIC_AGE_GROUP', 'VIC_RACE',
#        'VIC_SEX'],
#       dtype='object')

# %% [markdown]
# ###### CMPLNT_FR_DT

# %%
for item in sex_crimes.CMPLNT_FR_DT.unique():
    print(item)
# Out:
# 05/10/2016
# 04/06/2013
# 09/24/2017
# 06/02/2015
# 10/05/2017
# 12/01/2015
# 11/28/2012
# 01/31/2015
# 12/22/2013
# 08/11/2015
# 04/22/2012
# 06/13/2017
# 07/28/2013
# 06/05/1994
# 10/14/2015
# 09/27/2014
# 05/19/2012
# 03/26/2015
# 09/22/2013
# 02/17/2017
# 05/11/2008
# 07/24/2016
# 10/27/2012
# 08/22/2015
# 12/23/2017
# 08/07/2015
# 05/17/2016
# 01/01/2017
# 10/18/2012
# 06/30/2015
# 03/01/2012
# 09/12/2014
# 09/10/2016
# 05/06/2013
# 04/29/2015
# 04/15/2017
# 12/30/2016
# 08/17/2017
# 06/13/2016
# 08/22/2017
# 03/19/2012
# 08/28/2012
# 06/03/2014
# 05/16/2017
# 02/08/2012
# 05/27/2017
# 01/01/2011
# 01/14/2013
# 02/11/2016
# 04/07/2014
# 09/03/2012
# 01/04/2012
# 04/29/2016
# 03/03/2017
# 03/01/2015
# 12/01/2012
# 08/28/2015
# 05/03/2012
# 11/11/2013
# 04/24/2014
# 02/01/2015
# 06/14/2016
# 12/01/2014
# 06/01/2014
# 07/29/2015
# 10/09/2017
# 11/29/2012
# 02/10/2015
# 07/30/2014
# 01/01/2008
# 11/26/2012
# 06/04/2012
# 12/23/2016
# 11/27/2017
# 03/15/2015
# 05/22/2013
# ...

# %%
sex_crimes.query("CMPLNT_FR_DT=='04/05/1018'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6906406   614318253   04/05/1018     15:00:00         23.0  04/17/2018
#
#           OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 6906406  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
#
#            BORO_NM  ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  Latitude  \
# 6906406  MANHATTAN  ...        UNKNOWN     BLACK        M  40.78926
#
#          Longitude                        Lat_Lon            PATROL_BORO  \
# 6906406  -73.94771  (40.789260224, -73.947710001)  PATROL BORO MAN NORTH
#
#         VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 6906406           <18     BLACK        F
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("CMPLNT_FR_DT=='12/08/1025'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6968199   257555292   12/08/1025     15:00:00         66.0  05/16/2018
#
#           OFNS_DESC           PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD   BORO_NM  \
# 6968199  SEX CRIMES  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR  BROOKLYN
#
#          ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 6968199  ...        UNKNOWN   UNKNOWN        M  40.625769 -73.991417
#
#                                Lat_Lon              PATROL_BORO VIC_AGE_GROUP  \
# 6968199  (40.625768961, -73.991416822)  PATROL BORO BKLYN SOUTH         18-24
#
#          VIC_RACE  VIC_SEX
# 6968199     WHITE        F
#
# [1 rows x 25 columns]

# %%
# Drop rows that have dates with years that don't make sense
sex_crimes.drop(sex_crimes[sex_crimes['CMPLNT_FR_DT'] == '04/05/1018'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['CMPLNT_FR_DT'] == '12/08/1025'].index, inplace = True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ###### CMPLNT_FR_TM

# %%
for item in sex_crimes.CMPLNT_FR_TM.unique():
    print(item)
# Out:
# 10:00:00
# 21:30:00
# 15:45:00
# 22:30:00
# 20:38:00
# 11:24:00
# 16:00:00
# 19:35:00
# 14:56:00
# 20:00:00
# 01:00:00
# 15:30:00
# 02:30:00
# 00:01:00
# 14:30:00
# 23:37:00
# 11:00:00
# 05:30:00
# 12:00:00
# 06:30:00
# 04:30:00
# 02:50:00
# 08:20:00
# 02:55:00
# 01:55:00
# 18:02:00
# 15:00:00
# 17:30:00
# 21:00:00
# 20:10:00
# 19:15:00
# 11:20:00
# 09:00:00
# 19:00:00
# 17:40:00
# 07:40:00
# 18:55:00
# 22:00:00
# 18:00:00
# 08:00:00
# 20:30:00
# 00:00:00
# 01:30:00
# 00:20:00
# 13:00:00
# 03:00:00
# 22:40:00
# 20:50:00
# 14:00:00
# 02:18:00
# 09:30:00
# 17:00:00
# 06:00:00
# 08:59:00
# 02:00:00
# 23:00:00
# 16:50:00
# 07:31:00
# 07:15:00
# 21:10:00
# 21:40:00
# 04:00:00
# 03:58:00
# 08:30:00
# 11:50:00
# 18:08:00
# 15:18:00
# 00:15:00
# 00:22:00
# 17:05:00
# 10:50:00
# 19:25:00
# 12:30:00
# 03:15:00
# 23:30:00
# 17:28:00
# 14:20:00
# 11:03:00
# 22:19:00
# 20:05:00
# 07:00:00
# 08:40:00
# 15:40:00
# 12:45:00
# 01:50:00
# 16:30:00
# 19:20:00
# 05:50:00
# 03:10:00
# 20:40:00
# ...

# %% [markdown]
# ###### ADDR_PCT_CD

# %%
for item in sex_crimes.ADDR_PCT_CD.unique():
    print(item)
# Out:
# 49.0
# 103.0
# 107.0
# 83.0
# 122.0
# 32.0
# 102.0
# 110.0
# 115.0
# 48.0
# 106.0
# 30.0
# 41.0
# 73.0
# 33.0
# 17.0
# 79.0
# 40.0
# 24.0
# 114.0
# 113.0
# 77.0
# 47.0
# 67.0
# 13.0
# 60.0
# 88.0
# 42.0
# 62.0
# 101.0
# 75.0
# 109.0
# 23.0
# 14.0
# 52.0
# 43.0
# 68.0
# 44.0
# 94.0
# 19.0
# 46.0
# 34.0
# 50.0
# 72.0
# 84.0
# 90.0
# 28.0
# 25.0
# 81.0
# 111.0
# 66.0
# 63.0
# 104.0
# 10.0
# 70.0
# 120.0
# 18.0
# 7.0
# 45.0
# 61.0
# 121.0
# 112.0
# 78.0
# 9.0
# 26.0
# 108.0
# 69.0
# 71.0
# 22.0
# 105.0
# 1.0
# 5.0
# 123.0
# 20.0
# 100.0
# 6.0
# 76.0
# -99.0

# %%
sex_crimes.query("ADDR_PCT_CD == -99.0")
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 295388   365998895   12/24/2018     18:30:00        -99.0  01/17/2019
# 297326   436213844   01/18/2019     01:00:00        -99.0  01/19/2019
# 303045   725167396   01/23/2018     12:28:00        -99.0  01/29/2019
# 310018   325973169   03/27/2018     02:30:00        -99.0  01/29/2019
# 312363   506222419   04/10/2018     07:30:00        -99.0  01/29/2019
# 319112   507845354   01/27/2019     12:42:00        -99.0  02/05/2019
# 330629   449600896   09/15/2017     18:30:00        -99.0  02/21/2019
# 339517   388780984   02/09/2019     16:00:00        -99.0  02/10/2019
# 360960   672048068   12/20/2018     20:05:00        -99.0  03/07/2019
# 377142   807134687   03/17/2019     09:51:00        -99.0  04/03/2019
# 377291   561427712   06/08/2017     14:00:00        -99.0  04/03/2019
# 378576   106062813   03/21/2019     11:15:00        -99.0  04/03/2019
# ...

# %%
# drop rows where precinct address code is -99.0 because that doesn't exist
sex_crimes.drop(sex_crimes[sex_crimes['ADDR_PCT_CD'] == -99.0].index, inplace = True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ###### RPT_DT

# %%
for item in sex_crimes.RPT_DT.unique():
    print(item)
# Out:
# 05/10/2016
# 04/07/2013
# 09/24/2017
# 06/03/2015
# 10/05/2017
# 12/04/2015
# 11/28/2012
# 01/31/2015
# 12/23/2013
# 08/12/2015
# 04/23/2012
# 06/13/2017
# 07/28/2013
# 06/25/2017
# 11/03/2015
# 09/28/2014
# 05/24/2012
# 03/26/2015
# 02/10/2014
# 02/23/2017
# 04/25/2013
# 07/24/2016
# 10/27/2012
# 08/23/2015
# 12/23/2017
# 08/07/2015
# 05/17/2016
# 01/01/2017
# 10/18/2012
# 06/30/2015
# 03/10/2015
# 09/12/2014
# 09/12/2016
# 05/06/2013
# 04/29/2015
# 04/15/2017
# 05/31/2017
# 08/17/2017
# 06/17/2016
# 08/23/2017
# 03/26/2012
# 08/28/2012
# 06/03/2014
# 05/16/2017
# 02/23/2012
# 05/17/2017
# 05/28/2017
# 01/14/2011
# 01/15/2013
# 02/17/2016
# 04/07/2014
# 09/06/2012
# 01/05/2012
# 04/29/2016
# 04/05/2017
# 03/01/2015
# 12/01/2012
# 08/30/2015
# 05/04/2012
# 11/11/2013
# 04/24/2014
# 02/01/2017
# 06/14/2016
# 09/23/2015
# 09/09/2017
# 07/30/2015
# 10/09/2017
# 11/29/2012
# 02/27/2015
# 07/30/2014
# 03/19/2014
# 11/27/2012
# 07/06/2012
# 09/18/2017
# 11/27/2017
# 03/15/2015
# ...

# %% [markdown]
# ###### OFNS_DESC

# %%
sex_crimes.OFNS_DESC.unique()
# Out:
# array(['RAPE', 'SEX CRIMES', 'FELONY SEX CRIMES'], dtype=object)

# %% [markdown]
# ###### PD_DESC

# %%
sex_crimes.PD_DESC.unique()
# Out:
# array(['RAPE 1,ATTEMPT', 'RAPE 1', 'CHILD, ENDANGERING WELFARE',
#        'SEXUAL ABUSE 3,2', 'SODOMY 1', 'COURSE OF SEXUAL CONDUCT AGAIN',
#        'SEXUAL ABUSE', 'SEXUAL MISCONDUCT,INTERCOURSE',
#        'AGGRAVATED SEXUAL ASBUSE', 'OBSCENE MATERIAL - UNDER 17 YE',
#        'RAPE 3', 'OBSCENITY 1', 'OBSCENITY, PERFORMANCE 3', 'RAPE 2',
#        'SODOMY 3', 'SODOMY 2', 'SEX CRIMES', 'SEXUAL MISCONDUCT,DEVIATE',
#        'INCEST', 'OBSCENITY, MATERIAL 3', 'STALKING COMMIT SEX OFFENSE',
#        'INCEST 3', 'FAC. SEXUAL OFFENSE W/CONTROLL', 'SODOMY,CONSENSUAL',
#        'ABORTIONAL ARTICLES,ISSUING'], dtype=object)

# %%
sex_crimes.PD_DESC.value_counts()
# Out:
# SEXUAL ABUSE 3,2                  40387
# CHILD, ENDANGERING WELFARE        21116
# RAPE 1                            13410
# SODOMY 1                           5365
# SEXUAL MISCONDUCT,INTERCOURSE      4419
# AGGRAVATED SEXUAL ASBUSE           4340
# SEXUAL ABUSE                       4301
# RAPE 3                             2918
# RAPE 1,ATTEMPT                     2245
# RAPE 2                             2068
# OBSCENE MATERIAL - UNDER 17 YE     1521
# SODOMY 3                            532
# COURSE OF SEXUAL CONDUCT AGAIN      398
# SEXUAL MISCONDUCT,DEVIATE           338
# SODOMY 2                            319
# OBSCENITY 1                         189
# SEX CRIMES                          157
# OBSCENITY, PERFORMANCE 3            100
# OBSCENITY, MATERIAL 3                28
# STALKING COMMIT SEX OFFENSE          10
# INCEST                               10
# FAC. SEXUAL OFFENSE W/CONTROLL        5
# SODOMY,CONSENSUAL                     3
# ...

# %% [markdown]
# ###### CRM_ATPT_CPTD_CD

# %%
sex_crimes.CRM_ATPT_CPTD_CD.unique()
# Out:
# array(['ATTEMPTED', 'COMPLETED'], dtype=object)

# %% [markdown]
# ###### LAW_CAT_CD

# %%
sex_crimes.LAW_CAT_CD.unique()
# Out:
# array(['FELONY', 'MISDEMEANOR'], dtype=object)

# %% [markdown]
# ###### BORO_NM

# %%
sex_crimes.BORO_NM.unique()
# Out:
# array(['BRONX', 'QUEENS', 'BROOKLYN', 'STATEN ISLAND', 'MANHATTAN'],
#       dtype=object)

# %% [markdown]
# ###### LOC_OF_OCCUR_DESC

# %%
sex_crimes.LOC_OF_OCCUR_DESC.unique()
# Out:
# array(['FRONT OF', 'INSIDE', 'UNKNOWN', 'REAR OF', 'OPPOSITE OF'],
#       dtype=object)

# %% [markdown]
# ###### PREM_TYP_DESC

# %%
sex_crimes.PREM_TYP_DESC.unique()
# Out:
# array(['RESIDENCE-HOUSE', 'HOTEL/MOTEL', 'STREET',
#        'RESIDENCE - PUBLIC HOUSING', 'PARKING LOT/GARAGE (PUBLIC)',
#        'RESIDENCE - APT. HOUSE', 'PARKING LOT/GARAGE (PRIVATE)',
#        'OPEN AREAS (OPEN LOTS)', 'PUBLIC SCHOOL', 'TRANSIT - NYC SUBWAY',
#        'GYM/FITNESS FACILITY', 'GROCERY/BODEGA', 'BUS (NYC TRANSIT)',
#        'HOSPITAL', 'AIRPORT TERMINAL', 'OTHER',
#        'PRIVATE/PAROCHIAL SCHOOL', 'PUBLIC BUILDING',
#        'COMMERCIAL BUILDING', 'BAR/NIGHT CLUB', 'PARK/PLAYGROUND',
#        'CHAIN STORE', 'BRIDGE', 'RESTAURANT/DINER',
#        'DOCTOR/DENTIST OFFICE', 'DRY CLEANER/LAUNDRY', 'BUS TERMINAL',
#        'SYNAGOGUE', 'CANDY STORE', 'FOOD SUPERMARKET', 'CHURCH',
#        'FAST FOOD', 'TAXI (LIVERY LICENSED)', 'UNKNOWN',
#        'CLOTHING/BOUTIQUE', 'TRANSIT FACILITY (OTHER)',
#        'DEPARTMENT STORE', 'BUS STOP', 'BUS (OTHER)', 'TUNNEL',
#        'BEAUTY & NAIL SALON', 'TAXI (YELLOW LICENSED)',
# ...

# %%
sex_crimes.PREM_TYP_DESC.value_counts()
# Out:
# RESIDENCE - APT. HOUSE        39946
# RESIDENCE-HOUSE               14427
# STREET                        13117
# RESIDENCE - PUBLIC HOUSING     9627
# TRANSIT - NYC SUBWAY           6895
#                               ...
# VIDEO STORE                       8
# DAYCARE FACILITY                  2
# ATM                               2
# LOAN COMPANY                      2
# TRAMWAY                           1
# Name: PREM_TYP_DESC, Length: 73, dtype: int64

# %% [markdown]
# ###### JURIS_DESC

# %%
sex_crimes.JURIS_DESC.unique()
# Out:
# array(['N.Y. POLICE DEPT', 'N.Y. HOUSING POLICE', 'N.Y. TRANSIT POLICE',
#        'PORT AUTHORITY', 'POLICE DEPT NYC', 'N.Y. STATE PARKS',
#        'HEALTH & HOSP CORP', 'OTHER', 'LONG ISLAND RAILRD',
#        'STATN IS RAPID TRANS', 'N.Y. STATE POLICE', 'NYC PARKS',
#        'NEW YORK CITY SHERIFF OFFICE', 'U.S. PARK POLICE',
#        'DEPT OF CORRECTIONS', 'METRO NORTH', 'TRI-BORO BRDG TUNNL',
#        'AMTRACK', 'NYC DEPT ENVIRONMENTAL PROTECTION'], dtype=object)

# %% [markdown]
# ###### X_COORD_CD

# %%
sex_crimes.X_COORD_CD.unique()
# Out:
# array([1027295., 1041749., 1036790., 1006965.,  954943.,  999358.,
#        1030954., 1020255., 1018699., 1011779., 1028713.,  999794.,
#        1013232., 1008276., 1001936.,  992411.,  999634., 1004926.,
#         993336., 1007654., 1046367., 1003606., 1026387.,  998032.,
#         988874.,  990922.,  995188., 1008798.,  983393., 1053678.,
#        1017141., 1032198.,  998730.,  985679., 1017542., 1020316.,
#         978016., 1006434.,  997313.,  994276., 1011881., 1002106.,
#        1011257.,  983964.,  989013.,  997843.,  997376., 1000555.,
#        1005218., 1048565.,  986633., 1000448., 1013764.,  984623.,
#         991547.,  962748.,  988353.,  988708., 1032047.,  995244.,
#         942428., 1025420.,  991374.,  987624.,  996241.,  996793.,
#        1010641.,  998749.,  994010., 1057636.,  982285.,  984946.,
#         914725.,  991168., 1035212.,  982752.,  984160., 1016265.])

# %% [markdown]
# ###### Y_COORD_CD

# %%
sex_crimes.Y_COORD_CD.unique()
# Out:
# array([251236., 196938., 205267., 193571., 148360., 236472., 193887.,
#        210816., 215043., 246746., 187853., 241252., 236725., 183623.,
#        245282., 215025., 190253., 234532., 229488., 219564., 186986.,
#        185050., 262634., 175598., 207673., 149184., 190691., 238971.,
#        158818., 159044., 183798., 217060., 226827., 213954., 255919.,
#        239179., 172087., 244344., 204100., 218779., 250411., 249501.,
#        261130., 179071., 192652., 196573., 233927., 230994., 190528.,
#        216315., 167258., 168068., 195875., 209859., 168934., 174174.,
#        217918., 200317., 242037., 155739., 166536., 202485., 187228.,
#        203977., 236149., 210001., 175525., 181383., 224718., 203954.,
#        201682., 200203., 125837., 224929., 152992., 206772., 188429.,
#        227533.])

# %% [markdown]
# ###### SUSP_AGE_GROUP

# %%
sex_crimes.SUSP_AGE_GROUP.unique()
# Out:
# array(['25-44', 'UNKNOWN', '18-24', '45-64', '<18', '65+', '1017', '324',
#        '2018', '-978', '-941'], dtype=object)

# %%
sex_crimes.query("SUSP_AGE_GROUP=='1017'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 2860461   402073999   11/22/2017     18:30:00          1.0  11/23/2017
#
#           OFNS_DESC   PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD    BORO_NM  ...  \
# 2860461  SEX CRIMES  SODOMY 1        COMPLETED     FELONY  MANHATTAN  ...
#
#         SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 2860461           1017     BLACK        M  40.720255  -74.00709
#
#                               Lat_Lon            PATROL_BORO VIC_AGE_GROUP  \
# 2860461  (40.720255223, -74.00709028)  PATROL BORO MAN SOUTH         18-24
#
#          VIC_RACE  VIC_SEX
# 2860461     BLACK        F
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("SUSP_AGE_GROUP=='324'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 5599988   452079339   05/28/2006     22:30:00         28.0  05/29/2006
#
#         OFNS_DESC PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD    BORO_NM  ...  \
# 5599988      RAPE  RAPE 3        COMPLETED     FELONY  MANHATTAN  ...
#
#         SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  Latitude  Longitude  \
# 5599988            324     BLACK        M  40.80875 -73.952586
#
#                                Lat_Lon            PATROL_BORO VIC_AGE_GROUP  \
# 5599988  (40.808749904, -73.952585806)  PATROL BORO MAN NORTH           <18
#
#          VIC_RACE  VIC_SEX
# 5599988     BLACK        M
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("SUSP_AGE_GROUP=='2018'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6781117   513136424   11/25/2018     07:00:00         60.0  11/25/2018
#
#           OFNS_DESC           PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD   BORO_NM  \
# 6781117  SEX CRIMES  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR  BROOKLYN
#
#          ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 6781117  ...           2018   UNKNOWN        M  40.576157 -73.975984
#
#                            Lat_Lon              PATROL_BORO VIC_AGE_GROUP  \
# 6781117  (40.5761573, -73.9759838)  PATROL BORO BKLYN SOUTH         45-64
#
#          VIC_RACE  VIC_SEX
# 6781117     WHITE        F
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("SUSP_AGE_GROUP=='-978'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6788527   958886732   05/20/2018     00:01:00         20.0  05/20/2018
#
#           OFNS_DESC           PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 6788527  SEX CRIMES  SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
#
#            BORO_NM  ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX  Latitude  \
# 6788527  MANHATTAN  ...           -978     BLACK        M  40.78406
#
#          Longitude                        Lat_Lon            PATROL_BORO  \
# 6788527 -73.975021  (40.784059874, -73.975020513)  PATROL BORO MAN NORTH
#
#         VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 6788527         18-24     WHITE        F
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("SUSP_AGE_GROUP=='-941'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6856371   746798394   12/20/2018     05:30:00        107.0  12/20/2018
#
#         OFNS_DESC PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD BORO_NM  ...  \
# 6856371      RAPE  RAPE 3        COMPLETED     FELONY  QUEENS  ...
#
#         SUSP_AGE_GROUP                 SUSP_RACE SUSP_SEX   Latitude  \
# 6856371           -941  ASIAN / PACIFIC ISLANDER        M  40.729939
#
#          Longitude                        Lat_Lon               PATROL_BORO  \
# 6856371 -73.810433  (40.729939364, -73.810433142)  PATROL BORO QUEENS SOUTH
#
#         VIC_AGE_GROUP                        VIC_RACE  VIC_SEX
# 6856371         25-44  AMERICAN INDIAN/ALASKAN NATIVE        F
#
# [1 rows x 25 columns]

# %%
# Remove rows that have suspect age group column values that don't make sense
sex_crimes.drop(sex_crimes[sex_crimes['SUSP_AGE_GROUP'] == '1017'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['SUSP_AGE_GROUP'] == '324'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['SUSP_AGE_GROUP'] == '2018'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['SUSP_AGE_GROUP'] == '-978'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['SUSP_AGE_GROUP'] == '-941'].index, inplace = True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sex_crimes.SUSP_AGE_GROUP.unique()
# Out:
# array(['25-44', 'UNKNOWN', '18-24', '45-64', '<18', '65+'], dtype=object)

# %% [markdown]
# ###### SUSP_RACE

# %%
sex_crimes.SUSP_RACE.unique()
# Out:
# array(['WHITE HISPANIC', 'BLACK', 'UNKNOWN', 'WHITE', 'BLACK HISPANIC',
#        'ASIAN / PACIFIC ISLANDER', 'AMERICAN INDIAN/ALASKAN NATIVE',
#        'OTHER'], dtype=object)

# %% [markdown]
# ###### SUSP_SEX

# %%
sex_crimes.SUSP_SEX.unique()
# Out:
# array(['M', 'UNKNOWN', 'F', 'U'], dtype=object)

# %%
sex_crimes.SUSP_SEX.replace("U", "UNKNOWN", inplace=True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
sex_crimes.SUSP_SEX.unique()
# Out:
# array(['M', 'UNKNOWN', 'F'], dtype=object)

# %% [markdown]
# ##### Latitude

# %%
sex_crimes.Latitude.unique()
# Out:
# array([40.85616296, 40.70704748, 40.72993936, 40.69796351, 40.57384965,
#        40.81573205, 40.69873677, 40.74525274, 40.75686098, 40.84390125,
#        40.6821864 , 40.82885105, 40.81639185, 40.67065507, 40.8399082 ,
#        40.75687491, 40.68887215, 40.81039602, 40.79657114, 40.76930609,
#        40.67970041, 40.67458331, 40.88745131, 40.64865008, 40.73669807,
#        40.5761573 , 40.69008097, 40.82256992, 40.60260318, 40.60295159,
#        40.67110691, 40.76233422, 40.78926022, 40.75393894, 40.86905853,
#        40.8231013 , 40.63902167, 40.83732351, 40.72688262, 40.76717676,
#        40.85396027, 40.85148777, 40.88338258, 40.65819343, 40.69546894,
#        40.70622201, 40.8087499 , 40.80069433, 40.6896155 , 40.76018548,
#        40.62576896, 40.62797776, 40.70426739, 40.7426993 , 40.63036655,
#        40.64472613, 40.76481827, 40.71650772, 40.83088999, 40.59414517,
#        40.62368882, 40.72236369, 40.68057972, 40.72655402, 40.81485029,
# ...

# %% [markdown]
# ##### Longitude

# %%
sex_crimes.Longitude.unique()
# Out:
# array([-73.84439712, -73.7926119 , -73.81043314, -73.91808336,
#        -74.10549616, -73.94542041, -73.83156877, -73.87006287,
#        -73.87565666, -73.90050463, -73.83969048, -73.94383419,
#        -73.89529641, -73.91339092, -73.93608359, -73.97054406,
#        -73.94452903, -73.92531075, -73.96718569, -73.91550818,
#        -73.77604737, -73.93022154, -73.84760779, -73.95033556,
#        -73.98331603, -73.9759838 , -73.96055993, -73.91130717,
#        -74.00308766, -73.74997626, -73.88143296, -73.82691731,
#        -73.94771   , -73.99484365, -73.87963015, -73.86969046,
#        -74.02246352, -73.91983076, -73.95287135, -73.96380668,
#        -73.90012087, -73.93545797, -73.90233331, -74.00103224,
#        -73.98282508, -73.95097436, -73.95258581, -73.94110929,
#        -73.92439311, -73.76784258, -73.99141682, -73.94164716,
#        -73.89355376, -73.99865538, -73.97371261, -74.07748316,
#        -73.98518977, -73.9839199 , -73.82728462, -73.96041495,
# ...

# %% [markdown]
# ##### Lat_Lon

# %%
sex_crimes.Lat_Lon.unique()
# Out:
# array(['(40.856162957, -73.844397124)', '(40.707047475, -73.792611904)',
#        '(40.729939364, -73.810433142)', '(40.697963515, -73.918083362)',
#        '(40.573849649, -74.105496156)', '(40.815732053, -73.945420411)',
#        '(40.698736773, -73.831568765)', '(40.745252741, -73.87006287)',
#        '(40.756860977, -73.875656664)', '(40.843901255, -73.900504632)',
#        '(40.682186401, -73.839690483)', '(40.828851045, -73.943834191)',
#        '(40.816391847, -73.895296414)', '(40.670655072, -73.91339092)',
#        '(40.839908201, -73.936083587)', '(40.756874911, -73.970544057)',
#        '(40.688872153, -73.944529032)', '(40.810396019, -73.925310745)',
#        '(40.796571143, -73.967185687)', '(40.769306087, -73.91550818)',
#        '(40.679700408, -73.776047368)', '(40.674583308, -73.930221541)',
#        '(40.887451313, -73.847607787)', '(40.648650085, -73.950335563)',
#        '(40.73669807, -73.983316026)', '(40.5761573, -73.9759838)',
# ...

# %% [markdown]
# ##### PATROL_BORO

# %%
sex_crimes.PATROL_BORO.unique()
# Out:
# array(['PATROL BORO BRONX', 'PATROL BORO QUEENS SOUTH',
#        'PATROL BORO BKLYN NORTH', 'PATROL BORO STATEN ISLAND',
#        'PATROL BORO MAN NORTH', 'PATROL BORO QUEENS NORTH',
#        'PATROL BORO MAN SOUTH', 'PATROL BORO BKLYN SOUTH', 'UNKNOWN'],
#       dtype=object)

# %% [markdown]
# ##### VIC_AGE_GROUP

# %%
sex_crimes.VIC_AGE_GROUP.unique()
# Out:
# array(['<18', '25-44', '18-24', 'UNKNOWN', '45-64', '65+', '-2', '908',
#        '-1'], dtype=object)

# %%
sex_crimes.query("VIC_AGE_GROUP == '-2'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 1581423   342898922   07/24/2016     21:45:00         48.0  07/25/2016
#
#           OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 1581423  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
#
#         BORO_NM  ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 1581423   BRONX  ...          25-44     BLACK        M  40.843901 -73.900505
#
#                                Lat_Lon        PATROL_BORO VIC_AGE_GROUP  \
# 1581423  (40.843901255, -73.900504632)  PATROL BORO BRONX            -2
#
#          VIC_RACE  VIC_SEX
# 1581423     BLACK        M
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("VIC_AGE_GROUP == '908'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 4501485   689205716   03/02/2006     12:00:00         71.0  03/16/2006
#
#           OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 4501485  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
#
#           BORO_NM  ... SUSP_AGE_GROUP SUSP_RACE SUSP_SEX   Latitude  \
# 4501485  BROOKLYN  ...        UNKNOWN   UNKNOWN        F  40.664527
#
#          Longitude                        Lat_Lon              PATROL_BORO  \
# 4501485 -73.947739  (40.664527498, -73.947739291)  PATROL BORO BKLYN SOUTH
#
#         VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 4501485           908     BLACK        M
#
# [1 rows x 25 columns]

# %%
sex_crimes.query("VIC_AGE_GROUP == '-1'")
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 6200285   123960019   05/09/2008     11:00:00         72.0  05/21/2008
#
#           OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 6200285  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
#
#           BORO_NM  ... SUSP_AGE_GROUP                 SUSP_RACE SUSP_SEX  \
# 6200285  BROOKLYN  ...          18-24  ASIAN / PACIFIC ISLANDER        F
#
#           Latitude  Longitude                        Lat_Lon  \
# 6200285  40.658193 -74.001032  (40.658193432, -74.001032243)
#
#                      PATROL_BORO VIC_AGE_GROUP                  VIC_RACE  \
# 6200285  PATROL BORO BKLYN SOUTH            -1  ASIAN / PACIFIC ISLANDER
#
#          VIC_SEX
# 6200285        M
#
# [1 rows x 25 columns]

# %%
# Drop rows with victim age group values that don't make sense
sex_crimes.drop(sex_crimes[sex_crimes['VIC_AGE_GROUP'] == '-2'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['VIC_AGE_GROUP'] == '908'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['VIC_AGE_GROUP'] == '-1'].index, inplace = True)
# Out:
# /Users/varshagarla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sex_crimes.VIC_AGE_GROUP.unique()
# Out:
# array(['<18', '25-44', '18-24', 'UNKNOWN', '45-64', '65+'], dtype=object)

# %% [markdown]
# ##### VIC_RACE

# %%
sex_crimes.VIC_RACE.unique()
# Out:
# array(['WHITE HISPANIC', 'BLACK', 'UNKNOWN', 'WHITE',
#        'AMERICAN INDIAN/ALASKAN NATIVE', 'ASIAN / PACIFIC ISLANDER',
#        'BLACK HISPANIC', 'OTHER'], dtype=object)

# %% [markdown]
# ##### VIC_SEX

# %%
sex_crimes.VIC_SEX.unique()
# Out:
# array(['F', 'E', 'M', 'D', 'UNKNOWN'], dtype=object)

# %%
sex_crimes.VIC_SEX.value_counts()
# Out:
# F          86687
# M          15361
# E           2006
# D            118
# UNKNOWN        1
# Name: VIC_SEX, dtype: int64

# %%
# Remove row where victim sex is unknown since there is only one
# E is for PSNY (people of the state of NY), D is for businesses/organizations
# sex_crimes.drop(sex_crimes[sex_crimes['VIC_SEX'] == 'E'].index, inplace = True)
# sex_crimes.drop(sex_crimes[sex_crimes['VIC_SEX'] == 'D'].index, inplace = True)
sex_crimes.drop(sex_crimes[sex_crimes['VIC_SEX'] == 'UNKNOWN'].index, inplace = True)

# %%
sex_crimes.VIC_SEX.unique()
# Out:
# array(['F', 'E', 'M', 'D'], dtype=object)

# %%
sex_crimes.shape
# Out:
# (104172, 25)

# %%
sex_crimes.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'ADDR_PCT_CD', 'RPT_DT',
#        'OFNS_DESC', 'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'X_COORD_CD',
#        'Y_COORD_CD', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'Latitude',
#        'Longitude', 'Lat_Lon', 'PATROL_BORO', 'VIC_AGE_GROUP', 'VIC_RACE',
#        'VIC_SEX'],
#       dtype='object')

# %% [markdown]
# ##### LOC_OF_OCCUR_DESC

# %%
sex_crimes.LOC_OF_OCCUR_DESC.value_counts()
# Out:
# INSIDE         74666
# UNKNOWN        18579
# FRONT OF        9138
# REAR OF          937
# OPPOSITE OF      852
# Name: LOC_OF_OCCUR_DESC, dtype: int64

# %% [markdown]
# Can drop this column since the dataset footnotes say that to protect victim identities, rape and sex crime offenses have been located as occurring at the police station house within the precinct of occurrence.

# %%
sex_crimes.drop(['LOC_OF_OCCUR_DESC'], axis='columns', inplace=True)

# %%
sex_crimes.shape
# Out:
# (104172, 24)

# %%
sex_crimes.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'ADDR_PCT_CD', 'RPT_DT',
#        'OFNS_DESC', 'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'PREM_TYP_DESC', 'JURIS_DESC', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'Latitude', 'Longitude',
#        'Lat_Lon', 'PATROL_BORO', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
sex_crimes.PREM_TYP_DESC.unique()
# Out:
# array(['RESIDENCE-HOUSE', 'HOTEL/MOTEL', 'STREET',
#        'RESIDENCE - PUBLIC HOUSING', 'PARKING LOT/GARAGE (PUBLIC)',
#        'RESIDENCE - APT. HOUSE', 'PARKING LOT/GARAGE (PRIVATE)',
#        'OPEN AREAS (OPEN LOTS)', 'PUBLIC SCHOOL', 'TRANSIT - NYC SUBWAY',
#        'GYM/FITNESS FACILITY', 'GROCERY/BODEGA', 'BUS (NYC TRANSIT)',
#        'HOSPITAL', 'AIRPORT TERMINAL', 'OTHER',
#        'PRIVATE/PAROCHIAL SCHOOL', 'PUBLIC BUILDING',
#        'COMMERCIAL BUILDING', 'BAR/NIGHT CLUB', 'PARK/PLAYGROUND',
#        'CHAIN STORE', 'BRIDGE', 'RESTAURANT/DINER',
#        'DOCTOR/DENTIST OFFICE', 'DRY CLEANER/LAUNDRY', 'BUS TERMINAL',
#        'SYNAGOGUE', 'CANDY STORE', 'FOOD SUPERMARKET', 'CHURCH',
#        'FAST FOOD', 'TAXI (LIVERY LICENSED)', 'UNKNOWN',
#        'CLOTHING/BOUTIQUE', 'TRANSIT FACILITY (OTHER)',
#        'DEPARTMENT STORE', 'BUS STOP', 'BUS (OTHER)', 'TUNNEL',
#        'BEAUTY & NAIL SALON', 'TAXI (YELLOW LICENSED)',
# ...

# %% [markdown]
# ### Observe number of reports per year in dataset

# %%
7514 + 8963 + 8009 + 7561 + 7130 + 6655 + 6483 + 7159 + 7165 + 6990
# Out:
# 73629

# %%
sex_crimes[sex_crimes.CMPLNT_FR_DT.str.contains('2019|2018|2017|2016|2015|2014|2013|2012|2011|2010')]
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 59        659576310   05/10/2016     10:00:00         49.0  05/10/2016
# 355       248026406   04/06/2013     21:30:00        103.0  04/07/2013
# 446       964712641   09/24/2017     15:45:00        107.0  09/24/2017
# 544       713600785   06/02/2015     22:30:00         83.0  06/03/2015
# 554       921800581   10/05/2017     20:38:00        122.0  10/05/2017
# ...             ...          ...          ...          ...         ...
# 6983138   758182450   05/10/2018     23:30:00          6.0  05/11/2018
# 6983152   108620051   06/01/2018     02:30:00        110.0  06/18/2018
# 6983176   966604803   09/01/2015     16:00:00        100.0  03/26/2018
# 6983196   249377210   07/10/2018     19:00:00         14.0  07/10/2018
# 6983197   554488139   07/21/2018     06:15:00         42.0  07/21/2018
#
#           OFNS_DESC                        PD_DESC CRM_ATPT_CPTD_CD  \
# ...

# %%
sex_crimes[sex_crimes.CMPLNT_FR_DT.str.contains('2019')]
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 26646    777026494   01/01/2019     09:30:00         47.0  01/01/2019
# 276588   835532299   01/06/2019     00:46:00         63.0  01/06/2019
# 276600   962430382   01/13/2019     13:45:00          6.0  01/13/2019
# 276610   180291658   01/20/2019     00:01:00         40.0  01/20/2019
# 276617   453830423   01/22/2019     14:45:00         41.0  01/23/2019
# ...            ...          ...          ...          ...         ...
# 902869   283792647   12/16/2019     14:25:00         24.0  12/16/2019
# 903009   973196918   12/28/2019     01:00:00         63.0  12/28/2019
# 903120   665564477   12/28/2019     04:00:00         75.0  12/28/2019
# 903150   574415833   12/27/2019     22:00:00         46.0  12/28/2019
# 903345   380553766   12/30/2019     17:00:00         75.0  12/30/2019
#
#          OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# ...

# %%
# 7514 complaints from 2019
# 8963 complaints from 2018
# 8009 complaints from 2017
# 7561 complaints from 2016
# 7130 complaints from 2015
# 6655 complaints from 2014
# 6483 complaints from 2013
# 7159 complaints from 2012
# 7165 complaints from 2011
# 6990 complaints from 2010


# can already see that each year there are 6,000-8,000 complaints of sex crimes

# %%
7514 + 8963 + 8009 + 7561 + 7130 + 6655 + 6483 + 7159 + 7165 + 6990
# Out:
# 73629

# %% [markdown]
# ~74,000 complaints in dataset in the decade of 2010-2019

# %%
sex_crimes_2010_to_2019 = sex_crimes[sex_crimes.CMPLNT_FR_DT.str.contains('2010|2011|2012|2013|2014|2015|2016|2017|2018|2019')]

# %%
sex_crimes_2010_to_2019.shape
# Out:
# (73629, 24)

# %%
sex_crimes_2010_to_2019.to_csv('sex_crimes_2010_to_2019.csv')

# %%
sex_crimes_2010_to_2019.head()
# Out:
#      CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  \
# 59    659576310   05/10/2016     10:00:00         49.0  05/10/2016
# 355   248026406   04/06/2013     21:30:00        103.0  04/07/2013
# 446   964712641   09/24/2017     15:45:00        107.0  09/24/2017
# 544   713600785   06/02/2015     22:30:00         83.0  06/03/2015
# 554   921800581   10/05/2017     20:38:00        122.0  10/05/2017
#
#       OFNS_DESC                     PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 59         RAPE              RAPE 1,ATTEMPT        ATTEMPTED       FELONY
# 355        RAPE                      RAPE 1        COMPLETED       FELONY
# 446  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
# 544  SEX CRIMES  CHILD, ENDANGERING WELFARE        COMPLETED  MISDEMEANOR
# 554  SEX CRIMES            SEXUAL ABUSE 3,2        COMPLETED  MISDEMEANOR
#
#            BORO_NM  ... SUSP_AGE_GROUP       SUSP_RACE  SUSP_SEX   Latitude  \
# ...

# %%
7514 + 8963 + 8009
# Out:
# 24486

# %%
sex_crimes_2015_to_2019 = sex_crimes[sex_crimes.CMPLNT_FR_DT.str.contains('2015|2016|2017|2018|2019')]

# %%
sex_crimes_2015_to_2019.shape
# Out:
# (39177, 24)

# %%
sex_crimes_2017_to_2019 = sex_crimes[sex_crimes.CMPLNT_FR_DT.str.contains('2017|2018|2019')]

# %%
# sex_crimes_2017_to_2019.to_csv('sex_crimes_2017_to_2019.csv')

# %%
# sex_crimes_2015_to_2019.to_csv('sex_crimes_2015_to_2019.csv')

# %%
# sex_crimes_2010_to_2019.to_csv('sex_crimes_2010_to_2019.csv')
